# %%
class phones:
    def __init__(self,Phonename,ModelNumber,Price):
        self.PhoneName = PhoneName
        self.ModelNumber = ModelNumber
        self.Price = Price
    def getprice(self):
        return self.Price
    def getmodel(self):
        return self.ModelNumber
    def __str__(self):
        return self.PhoneName + ':'+str(self.getmodel())+'::' + str(self.getprice())
def prices(rec,PhoneName,ModelNumber,Price):
    rec.append(phones(PhoneName,ModelNumber,Price))
    return rec
record = []
x = input('enter Y as yes and N as no to enter phone details')
while x == 'Y':
    PhoneName= input('Phone Name:')
    ModelNumber = input('Model Number:')
    Price = input('Price:')
    record = prices(record,PhoneName,ModelNumber,Price)
    x = input('enter Y as yes and N as no to enter phone details')
n = 1
print("--------The List of the phone that the store have -------")
for item in record:
    print(n, '-', item)
    n = n + 1
# Out:
# enter Y as yes and N as no to enter phone detailsY
# Phone Name:Samsung Galaxy
# Model Number:S10
# Price:300,000
# enter Y as yes and N as no to enter phone detailsY
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-2e82ca3f013f> in <module>
#      16 x = input('enter Y as yes and N as no to enter phone details')
#      17 while x == 'Y':
# ---> 18     PhoneName= input('Phone Name:')
#      19     ModelNumber = input('Model Number:')
#      20     Price = input('Price:')
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# --> 860         return self._input_request(str(prompt),
#     861             self._parent_ident,
#     862             self._parent_header,
#
# ...

# %% [markdown]
# # file and writing

# %%
file = open('demo.txt','w')
file.write('''Work Title :PHONE STORE (MOBILE SHOP) RECORD MANAGEMENT
enter Y as yes and N as no to enter phone detailsY
Phone Name:Samsung Galaxy
Model Number:S10
Price:300,000
enter Y as yes and N as no to enter phone detailsY
''')
file.close()

# %% [markdown]
# # To read file

# %%
file1 = open('Day3.ipynb','r')
print(file1.read())
# Out:
# {
#  "cells": [
#   {
#    "cell_type": "markdown",
#    "metadata": {},
#    "source": [
#     "## ADVANCED DATA TYPES\n",
#     "# Tuple"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": 1,
#    "metadata": {},
#    "outputs": [
#     {
#      "name": "stdout",
#      "output_type": "stream",
#      "text": [
#       "<class 'tuple'>\n"
#      ]
#     }
#    ],
#    "source": [
#     "numbers= (78,52,96,85,52,100,105,52,20,28,35,40)\n",
#     "print(type(numbers)) # type function will return the data type of the value assigned to the variable"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": 3,
#    "metadata": {},
#    "outputs": [
#     {
#      "name": "stdout",
#      "output_type": "stream",
#      "text": [
#       "12\n"
#      ]
#     }
#    ],
#    "source": [
#     "print(len(numbers)) # len function will return the lenght of values your variable is holding"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": 4,
# ...

# %%
file2 = open('demo.txt','a')
file2.write('''PYTHON IS AN AMAZING PROGRAMING LANGUAGE, ALTHOUGH IT IS SO TECHNICAL,STICK TP IT''')
file2.close()

# %%
file3 = open('demo.txt','r+') #means read before append
print(file3.read())
file3.write('''EARLY CODE IS NOT BAD''')
file3.close()
# Out:
# Work Title :PHONE STORE (MOBILE SHOP) RECORD MANAGEMENT
# enter Y as yes and N as no to enter phone detailsY
# Phone Name:Samsung Galaxy
# Model Number:S10
# Price:300,000
# enter Y as yes and N as no to enter phone detailsY
# PYTHON IS AN AMAZING PROGRAMING LANGUAGE, ALTHOUGH IT IS SO TECHNICAL,STICK TP ITPYTHON IS AN AMAZING PROGRAMING LANGUAGE, ALTHOUGH IT IS SO TECHNICAL,STICK TP IT
